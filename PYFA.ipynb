# %% [markdown]
# #Mika3.1Tanh

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
ticker = "PYFA.JK"
start_date = "2021-12-31"
end_date = "2023-12-18"

data = yf.download(ticker, start=start_date, end=end_date)

print(data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#               Open    High     Low   Close  Adj Close   Volume
# Date
# 2022-01-03  1015.0  1020.0  1005.0  1015.0     1015.0    43300
# 2022-01-04  1025.0  1025.0  1010.0  1010.0     1010.0    51700
# 2022-01-05  1025.0  1025.0  1005.0  1010.0     1010.0    43800
# 2022-01-06  1010.0  1020.0  1000.0  1010.0     1010.0   165600
# 2022-01-07  1015.0  1015.0  1000.0  1010.0     1010.0    67000
# ...            ...     ...     ...     ...        ...      ...
# 2023-12-11  1185.0  1200.0  1110.0  1140.0     1140.0   721400
# 2023-12-12  1125.0  1135.0   865.0   880.0      880.0  5046500
# 2023-12-13   880.0   980.0   880.0   915.0      915.0  2264800
# 2023-12-14   920.0  1100.0   875.0  1075.0     1075.0  2738100
# 2023-12-15  1080.0  1150.0  1030.0  1070.0     1070.0  1064500
#
# [477 rows x 6 columns]

# %%
import math
import numpy as np
from sklearn.preprocessing import MinMaxScaler


# Extract the 'Close' column from the data
close_prices = data['Close']

# Get the values from the 'Close' column as a NumPy array
values = close_prices.values

# Calculate the length of the training data by taking 80% of the total length of the 'values' array
training_data_len = math.ceil(len(values) * 0.8)

# Split the scaled data into training and test sets

train_data = close_prices[0 : training_data_len].values.reshape(-1,1)

#test_data = scaled_data[training_data_len - 30: , : ]
test_data = close_prices[training_data_len - 30 :].values.reshape(-1,1)

# Create a MinMaxScaler object and scale the values to the range [0, 1]
scaler = MinMaxScaler()
# scaled_data_train = scaler.fit_transform(train_data.reshape(-1, 1))
scaled_data_train = scaler.fit_transform(train_data)
scaled_data_test = scaler.fit_transform(test_data)


# Initialize empty lists for the training and test inputs and outputs
x_train, y_train = [], []
x_test = []

# Loop through the training data and create input/output pairs
for i in range(30, len(train_data)):
    x_train.append(scaled_data_train[i - 30: i, 0])
    y_train.append(scaled_data_train[i, 0])

# Convert the training inputs and outputs to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the training inputs to be 3D for use with an LSTM model
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# Loop through the test data and create input sequences
for i in range(30, len(test_data)):
    x_test.append(scaled_data_test[i - 30: i, 0])

# Convert the test inputs to a NumPy array and reshape to be 3D
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the test outputs as a NumPy array from the 'values' array
y_test = values[training_data_len:]

print('x_train shape:', x_train.shape)
print('y_train shape:', y_train.shape)
print('x_test shape:', x_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# x_train shape: (352, 30, 1)
# y_train shape: (352,)
# x_test shape: (95, 30, 1)
# y_test shape: (95,)

# %%
len(test_data)
# Out:
# 125

# %%
# Set seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

model = keras.Sequential()
model.add(layers.LSTM(50, activation='tanh',return_sequences=True, kernel_initializer="glorot_uniform", input_shape=(x_train.shape[1], 1)))
model.add(layers.Dropout(0.2))  # Contoh penggunaan Dropout
model.add(layers.LSTM(50, return_sequences=True))
model.add(layers.Dropout(0.2))  # Contoh penggunaan Dropout
model.add(layers.LSTM(60, return_sequences=True))
model.add(layers.Dropout(0.2))  # Contoh penggunaan Dropout
model.add(layers.LSTM(60, return_sequences=False))
model.add(layers.Dropout(0.2))  # Contoh penggunaan Dropout
model.add(layers.Dense(1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 50)            10400
#
#  dropout (Dropout)           (None, 30, 50)            0
#
#  lstm_1 (LSTM)               (None, 30, 50)            20200
#
#  dropout_1 (Dropout)         (None, 30, 50)            0
#
#  lstm_2 (LSTM)               (None, 30, 60)            26640
#
#  dropout_2 (Dropout)         (None, 30, 60)            0
#
#  lstm_3 (LSTM)               (None, 60)                29040
#
#  dropout_3 (Dropout)         (None, 60)                0
#
#  dense (Dense)               (None, 1)                 61
#
# =================================================================
# Total params: 86341 (337.27 KB)
# Trainable params: 86341 (337.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define and compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Fit model dengan jumlah epochs yang ditentukan
model.fit(x_train, y_train, batch_size=16, epochs=200)
# Out:
# Epoch 1/200
# 22/22 [==============================] - 16s 65ms/step - loss: 0.0659
# Epoch 2/200
# 22/22 [==============================] - 1s 68ms/step - loss: 0.0178
# Epoch 3/200
# 22/22 [==============================] - 1s 64ms/step - loss: 0.0137
# Epoch 4/200
# 22/22 [==============================] - 1s 66ms/step - loss: 0.0126
# Epoch 5/200
# 22/22 [==============================] - 2s 69ms/step - loss: 0.0123
# Epoch 6/200
# 22/22 [==============================] - 2s 70ms/step - loss: 0.0107
# Epoch 7/200
# 22/22 [==============================] - 2s 93ms/step - loss: 0.0109
# Epoch 8/200
# 22/22 [==============================] - 2s 86ms/step - loss: 0.0116
# Epoch 9/200
# 22/22 [==============================] - 1s 68ms/step - loss: 0.0121
# Epoch 10/200
# 22/22 [==============================] - 1s 65ms/step - loss: 0.0126
# Epoch 11/200
# 22/22 [==============================] - 1s 65ms/step - loss: 0.0112
# Epoch 12/200
# 22/22 [==============================] - 1s 65ms/step - loss: 0.0110
# Epoch 13/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0102
# Epoch 14/200
# 22/22 [==============================] - 1s 65ms/step - loss: 0.0103
# Epoch 15/200
# 22/22 [==============================] - 1s 65ms/step - loss: 0.0089
# Epoch 16/200
# 22/22 [==============================] - 2s 98ms/step - loss: 0.0097
# Epoch 17/200
# 22/22 [==============================] - 2s 109ms/step - loss: 0.0097
# Epoch 18/200
# 22/22 [==============================] - 2s 98ms/step - loss: 0.0092
# Epoch 19/200
# 22/22 [==============================] - 2s 103ms/step - loss: 0.0095
# Epoch 20/200
# 22/22 [==============================] - 2s 86ms/step - loss: 0.0082
# Epoch 21/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0093
# Epoch 22/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0083
# Epoch 23/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0081
# Epoch 24/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0079
# Epoch 25/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0088
# Epoch 26/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0076
# Epoch 27/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0075
# Epoch 28/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0076
# Epoch 29/200
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0078
# Epoch 30/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0070
# Epoch 31/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0068
# Epoch 32/200
# 22/22 [==============================] - 1s 59ms/step - loss: 0.0061
# Epoch 33/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0065
# Epoch 34/200
# 22/22 [==============================] - 1s 59ms/step - loss: 0.0061
# Epoch 35/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0073
# Epoch 36/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0061
# Epoch 37/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0069
# Epoch 38/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0063
# Epoch 39/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0071
# Epoch 40/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0056
# Epoch 41/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0058
# Epoch 42/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0053
# Epoch 43/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0053
# Epoch 44/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0051
# Epoch 45/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0052
# Epoch 46/200
# 22/22 [==============================] - 1s 49ms/step - loss: 0.0054
# Epoch 47/200
# 22/22 [==============================] - 1s 66ms/step - loss: 0.0062
# Epoch 48/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0063
# Epoch 49/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0057
# Epoch 50/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0059
# Epoch 51/200
# 22/22 [==============================] - 1s 37ms/step - loss: 0.0062
# Epoch 52/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0053
# Epoch 53/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0053
# Epoch 54/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0052
# Epoch 55/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0058
# Epoch 56/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0058
# Epoch 57/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0064
# Epoch 58/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0056
# Epoch 59/200
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0047
# Epoch 60/200
# 22/22 [==============================] - 1s 47ms/step - loss: 0.0045
# Epoch 61/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0043
# Epoch 62/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0052
# Epoch 63/200
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0051
# Epoch 64/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0044
# Epoch 65/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0052
# Epoch 66/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0049
# Epoch 67/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0042
# Epoch 68/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0049
# Epoch 69/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0045
# Epoch 70/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0050
# Epoch 71/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0044
# Epoch 72/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0052
# Epoch 73/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0042
# Epoch 74/200
# 22/22 [==============================] - 1s 48ms/step - loss: 0.0041
# Epoch 75/200
# 22/22 [==============================] - 1s 60ms/step - loss: 0.0047
# Epoch 76/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0042
# Epoch 77/200
# 22/22 [==============================] - 1s 46ms/step - loss: 0.0048
# Epoch 78/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0055
# Epoch 79/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0047
# Epoch 80/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0048
# Epoch 81/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0039
# Epoch 82/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0042
# Epoch 83/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0044
# Epoch 84/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0046
# Epoch 85/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0043
# Epoch 86/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0048
# Epoch 87/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0037
# Epoch 88/200
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0040
# Epoch 89/200
# 22/22 [==============================] - 2s 98ms/step - loss: 0.0043
# Epoch 90/200
# 22/22 [==============================] - 1s 65ms/step - loss: 0.0041
# Epoch 91/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0040
# Epoch 92/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0039
# Epoch 93/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0041
# Epoch 94/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0045
# Epoch 95/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0036
# Epoch 96/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0042
# Epoch 97/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0040
# Epoch 98/200
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0036
# Epoch 99/200
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0038
# Epoch 100/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0042
# Epoch 101/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0041
# Epoch 102/200
# 22/22 [==============================] - 1s 47ms/step - loss: 0.0048
# Epoch 103/200
# 22/22 [==============================] - 1s 63ms/step - loss: 0.0035
# Epoch 104/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0040
# Epoch 105/200
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0040
# Epoch 106/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0042
# Epoch 107/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0044
# Epoch 108/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0040
# Epoch 109/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0040
# Epoch 110/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0040
# Epoch 111/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0039
# Epoch 112/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0039
# Epoch 113/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0034
# Epoch 114/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0035
# Epoch 115/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0036
# Epoch 116/200
# 22/22 [==============================] - 1s 45ms/step - loss: 0.0033
# Epoch 117/200
# 22/22 [==============================] - 1s 61ms/step - loss: 0.0034
# Epoch 118/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0031
# Epoch 119/200
# 22/22 [==============================] - 1s 50ms/step - loss: 0.0036
# Epoch 120/200
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0036
# Epoch 121/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0038
# Epoch 122/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0035
# Epoch 123/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0037
# Epoch 124/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0034
# Epoch 125/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0038
# Epoch 126/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0032
# Epoch 127/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0033
# Epoch 128/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0031
# Epoch 129/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0033
# Epoch 130/200
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0035
# Epoch 131/200
# 22/22 [==============================] - 1s 63ms/step - loss: 0.0031
# Epoch 132/200
# 22/22 [==============================] - 1s 60ms/step - loss: 0.0035
# Epoch 133/200
# 22/22 [==============================] - 1s 52ms/step - loss: 0.0031
# Epoch 134/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0032
# Epoch 135/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0031
# Epoch 136/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0031
# Epoch 137/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0032
# Epoch 138/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0032
# Epoch 139/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0031
# Epoch 140/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0032
# Epoch 141/200
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0031
# Epoch 142/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0035
# Epoch 143/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0040
# Epoch 144/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0028
# Epoch 145/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0035
# Epoch 146/200
# 22/22 [==============================] - 1s 61ms/step - loss: 0.0037
# Epoch 147/200
# 22/22 [==============================] - 1s 56ms/step - loss: 0.0030
# Epoch 148/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0030
# Epoch 149/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0033
# Epoch 150/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0029
# Epoch 151/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0031
# Epoch 152/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0032
# Epoch 153/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0029
# Epoch 154/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0031
# Epoch 155/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0032
# Epoch 156/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0032
# Epoch 157/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0029
# Epoch 158/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0031
# Epoch 159/200
# 22/22 [==============================] - 1s 59ms/step - loss: 0.0031
# Epoch 160/200
# 22/22 [==============================] - 1s 60ms/step - loss: 0.0036
# Epoch 161/200
# 22/22 [==============================] - 1s 59ms/step - loss: 0.0030
# Epoch 162/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0030
# Epoch 163/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0030
# Epoch 164/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0033
# Epoch 165/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0031
# Epoch 166/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0028
# Epoch 167/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0026
# Epoch 168/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0032
# Epoch 169/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0028
# Epoch 170/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0025
# Epoch 171/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0027
# Epoch 172/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0029
# Epoch 173/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0028
# Epoch 174/200
# 22/22 [==============================] - 1s 60ms/step - loss: 0.0028
# Epoch 175/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0028
# Epoch 176/200
# 22/22 [==============================] - 1s 42ms/step - loss: 0.0029
# Epoch 177/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0035
# Epoch 178/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0033
# Epoch 179/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0029
# Epoch 180/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0030
# Epoch 181/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0028
# Epoch 182/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0028
# Epoch 183/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0026
# Epoch 184/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0027
# Epoch 185/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0025
# Epoch 186/200
# 22/22 [==============================] - 1s 38ms/step - loss: 0.0025
# Epoch 187/200
# 22/22 [==============================] - 1s 44ms/step - loss: 0.0026
# Epoch 188/200
# 22/22 [==============================] - 1s 60ms/step - loss: 0.0029
# Epoch 189/200
# 22/22 [==============================] - 1s 62ms/step - loss: 0.0025
# Epoch 190/200
# 22/22 [==============================] - 1s 51ms/step - loss: 0.0024
# Epoch 191/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0027
# Epoch 192/200
# 22/22 [==============================] - 1s 41ms/step - loss: 0.0024
# Epoch 193/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0023
# Epoch 194/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0026
# Epoch 195/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0030
# Epoch 196/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0023
# Epoch 197/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0024
# Epoch 198/200
# 22/22 [==============================] - 1s 40ms/step - loss: 0.0028
# Epoch 199/200
# 22/22 [==============================] - 1s 39ms/step - loss: 0.0025
# Epoch 200/200
# 22/22 [==============================] - 1s 61ms/step - loss: 0.0025

# %%
predictions = model.predict(x_train)

predictions = scaler.inverse_transform(predictions.reshape(-1,1))
y_train = scaler.inverse_transform(y_train.reshape(-1,1))

mse = mean_squared_error(predictions, y_train)
rmse = np.sqrt(mse)
print('Root mean squared error:', rmse)
# Out:
# 11/11 [==============================] - 2s 15ms/step
# Root mean squared error: 30.221349465943003

# %%
predictions = model.predict(x_test)

predictions = scaler.inverse_transform(predictions.reshape(-1,1))

mse = mean_squared_error(predictions, y_test)
rmse = np.sqrt(mse)
print('Root mean squared error:', rmse)
# Out:
# 3/3 [==============================] - 2s 19ms/step
# Root mean squared error: 91.89238482694944

# %%
plt.figure(figsize=(16,7))

plt.plot(predictions, 'r', marker='.', label='Predicted Test')
plt.plot(y_test, marker='.', label='Actual Test')

plt.legend()
plt.show()

# %%
# Ambil 30 hari terakhir sebagai last_sequence
last_sequence = scaled_data_test[-30:]

# Inisialisasi tanggal terakhir
last_date = datetime.strptime(end_date, '%Y-%m-%d')
last_date = last_date - timedelta(days=1)
last_date = last_date.date()

# Lakukan prediksi untuk 30 hari ke depan
future_predictions = []
future_dates = []
future_days = 22

for _ in range(future_days):
    next_date = last_date + timedelta(days=1)

    # Lewati hari Sabtu dan Minggu (indeks 5 atau 6)
    while next_date.weekday() >= 5:
        next_date += timedelta(days=1)

    reshaped_sequence = last_sequence.reshape(1, last_sequence.shape[0], 1)

    # Prediksi harga untuk satu hari ke depan menggunakan model_saved
    prediction = model.predict(reshaped_sequence)[0][0]
    future_predictions.append(prediction)
    future_dates.append(next_date)

    # Perbarui urutan terakhir dengan menambahkan prediksi baru dan menghapus harga pertama dalam urutan
    last_sequence = np.append(last_sequence[1:], prediction)

    last_date = next_date

# Lakukan inversi scaling pada prediksi
future_predictions = np.array(future_predictions).reshape(-1, 1)
future_predictions = scaler.inverse_transform(future_predictions)

# Buat dataframe dari hasil prediksi
predicted_df = pd.DataFrame({'Tanggal': future_dates, 'Prediksi_Harga': future_predictions.flatten()})

# Tampilkan hasil prediksi
print(predicted_df)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
#        Tanggal  Prediksi_Harga
# 0   2023-12-18     1002.979248
# 1   2023-12-19      989.939392
# 2   2023-12-20      970.182739
# 3   2023-12-21      950.020935
# 4   2023-12-22      930.725647
# 5   2023-12-25      914.785034
# 6   2023-12-26      902.796997
# 7   2023-12-27      894.450317
# 8   2023-12-28      890.781067
# 9   2023-12-29      891.648071
# 10  2024-01-01      896.532349
# 11  2024-01-02      905.170471
# 12  2024-01-03      916.587891
# 13  2024-01-04      929.854065
# 14  2024-01-05      944.224121
# 15  2024-01-08      958.910828
# 16  2024-01-09      973.238953
# 17  2024-01-10      986.666870
# 18  2024-01-11      998.477051
# 19  2024-01-12     1008.532349
# 20  2024-01-15     1016.047241
# 21  2024-01-16     1021.541687
